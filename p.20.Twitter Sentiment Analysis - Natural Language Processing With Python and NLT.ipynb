# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import sentiment_mod as s

#consumer key, consumer secret, access token, access secret.
ckey="JAZOt71C3AdBcRiRnfFzUekpo"
csecret="kF3YVQIK9k3wQAniHrQ7108DHCznDsfqyAKl1bS6P65cvgbAS6"
atoken="14758586-MQHSWLaUPXRUTr6ENM16w424rnkEEf0PE7oQFJTZA"
asecret="fnUlPaRhujxEJKdseJWlx5F0trOXGfA6LCbe0pymQIyOy"


class listener(StreamListener):

    def on_data(self, data):

        all_data = json.loads(data)
        if "text" in all_data:

            tweet = all_data["text"]
            sentiment_value, confidence = s.sentiment(tweet)
            print(tweet, sentiment_value, confidence)

            if confidence*100 >= 80:
                output = open("twitter-out.txt","a")
                output.write(sentiment_value)
                output.write('\n')
                output.close()

        return True

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["transportation"])
# Out:
# #Energy, #Mobility &amp; #Transportation in #NewYork: a video recap of an @AdvancedNRG stakeholder series last year tha… https://t.co/lpBrpr0RKj neg 1.0
# RT @KristaSimpson: The Ministry of Transportation confirms the scheduled closure of the Victoria St. bridge has been postponed until tomorr… neg 0.8
# SENIORS! Scioto Downs Casino Trip: Monday March 26th. $30 due at sign up at XARSC. Includes charter bus transportat… https://t.co/AXguE3OrjF neg 1.0
# RT @charlesadler: Crude Reality - This wk "Cdn benchmark Western Canadian Select was trading at $33.57/barrel, after falling $8 in two days… neg 0.8
# #Energy, #Mobility &amp; #Transportation in #NewYork: a video recap of an @AdvancedNRG stakeholder series last year tha… https://t.co/ldCpyyqwb7 neg 1.0
# Starting Feb 07 join me at noon for one hour of worship at The Mount Chapel location. Transportation available from City Hall! pos 1.0
# RT @AlphaPsiAlphas: Step into Wakanda along with the Brothers of Alpha Phi Alpha! Thursday February 15, 2018 join us for a special midnight… neg 1.0
# We're #hiring! Click to apply: Team Owner Operator Truck Drivers, CDL A - https://t.co/YleUYzxMBc #Transportation… https://t.co/w6wHpQEgoW neg 0.8
# RT @ALDUB_Joy25: @ALDUB_POETweets @lynieg88 @ofc_ALDUBHK @Salvesayson @grabesila @xanria_018 @Aryanlu85 @ermiesagum @mayora_09 @japple003 @… neg 0.8
# Interested in a #job in #Salina, KS? This could be a great fit: https://t.co/f8KR2A6elz #Transportation #Hiring #CareerArc neg 1.0
# American Express Global Business Travel 2018 Forecast Indicates Moderate Price Increase Across Air, Hotel and Groun… https://t.co/SzGMOrFDQR neg 0.8
# We're #hiring! Read about our latest #job opening here: Class A CDL Truck Driver, Owner Operator -… https://t.co/MQISf644nu neg 1.0
# APICS na aChain: CLTD (Certified in Logistics, Transportation and Distribution), CPIM (Certified in Production and… https://t.co/kclYy6UDJL neg 0.8
# We're #hiring! Click to apply: Airway Transportation Systems Specialist (Electronics: RADAR, Navigational Aides, Co… https://t.co/Sp9eBnYoJd neg 0.8
# Interested in a #job in #Wheaton, IL? This could be a great fit: https://t.co/g0ZF36hcEU #Transportation #Hiring #CareerArc neg 1.0
# RT @RikAdamski: Civil engineering is a physical science. It deals in inalterable laws of physics.
#
# Transportation engineering is a social *… pos 1.0
# Mayors Skeptical of Trump Infrastructure Plan https://t.co/NLNzmfARGS neg 0.8
# RT @tmj_nj_eng: This #job might be a great fit for you: Airspace System Inspection Pilot - https://t.co/NKl1dAxkXd #Transportation #Atlanti… neg 1.0
# RT @dadtellsjokes: What do ballerinas take for transportation? A tutu train neg 0.8
# RT @mwr_dbm: Every time my city discusses building light rail from the airport to downtown, I am like 🤦‍♀️We need transportation for poor p… neg 1.0
# @MSNBC @Google @YouTube @sundarpichai @SusanWojcicki https://t.co/DgfzYICAoL neg 0.8
# RT @Sarajohnp: "You can't understand a city without using its public transportation system"
#
#  @dhanuraj, MLA @HibiEden, KMRL MD  and the p… neg 1.0
# RT @WellingMichael: Citizens are transported like farm animals in #socialist #Venezuela as public transportation collapses https://t.co/nHX… neg 1.0
# An important reminder that while "skills" are essential, it takes so much more to tackle unemployment in low-income… https://t.co/zGUh59W8IQ pos 1.0
# Whitewash ! https://t.co/AenRM6U2zp neg 0.8
# #New #York #NY #USA - Equity Research Associate - Transportation - Equity Research Associate - Transportation… https://t.co/9XuZzEEGoE neg 0.8
# RT @pdacosta: Imagine finding a job and not being able to access or afford transportation to get there. It happens to millions of Americans… pos 1.0
# We're excited to head to Dallas today for the @NITL Transportation Summit today! https://t.co/2tbE5mKGT7 neg 0.8
# Costs Balloon for California's High-Speed Rail https://t.co/CdOPUKW0vT neg 0.8
# Interested in a #job in #Hamilton, ON? This could be a great fit: https://t.co/IqJt6aSH69 #Transportation #Hiring #CareerArc neg 1.0
# God i hate public transportation - neg 1.0
# As a leader in providing quality long-term care, Diversicare takes pride in our employees. If you or someone you kn… https://t.co/ODLJBQgqID neg 0.8
# @MSNBC @Recode @sundarpichai @SusanWojcicki https://t.co/DgfzYICAoL neg 0.8
# Government to complete AI sale by next fiscal: Survey
# https://t.co/oyGQ7byIP5 neg 1.0
# See our latest #Hughes, AR #job and click to apply: OTR Team Company Driver CDL A - https://t.co/7sZAKo0vfT… https://t.co/RiAsA02Vg4 neg 1.0
# DON'T RIDE PUBLIC TRANSPORTATION, kung wala kang care mag abot ng bayad sa jeepney ☺☺☺ PLEASE! neg 0.8
# RT @dadtellsjokes: What do ballerinas take for transportation? A tutu train neg 0.8
# Want to work in #Charleston, SC? View our latest opening: https://t.co/ULFapQOIrB #Transportation #Job #Jobs #Hiring #CareerArc neg 1.0
# RT @chadinabhan: One of the major barriers to enrollment in clinical trials is transportation logistics to large academic sites. Need to th… neg 1.0
# RT @Smart_Transp: The latest Smart Transportation! https://t.co/uLRKvnOB5V Thanks to @WBG_Transport @PortTechnology @infra_intel neg 1.0
# RT @DoTopia: 78% of restaurants say transportation is the #1 barrier to donating food. Thanks for sharing this important story @causeartist… pos 1.0
# RT @PCANC: What do you think would happen if more family physicians had the resources, tools and time to have more meaningful conversations… neg 0.8
# Check out this infographic!
#
# #Transportation #management #Ecommerce #amazon #target #bestbuy #walmart #apple… https://t.co/Fm2PVu7qON neg 0.8
# #cbuzz host @MikaelaHuntNews sat down with Chet Ridenour of @car2goColumbus and talked all things transportation an… https://t.co/aMOlUU9mME neg 1.0
# #Transportation Manager #Transportation Manager Large Heavy Civil Construction company and materials provider is lo… https://t.co/CV5MoMc9gH neg 0.8
# #Transportation Manager #Transportation Manager Large Heavy Civil Construction company and materials provider is lo… https://t.co/4TLhqVNBmf neg 0.8
# #Transportation Manager #Transportation Manager Large Heavy Civil Construction company and materials provider is lo… https://t.co/eEd7vL0ojD neg 0.8
# #Transportation Manager #Transportation Manager Large Heavy Civil Construction company and materials provider is lo… https://t.co/C6rXXWAYO7 neg 0.8
# #Transportation Manager #Transportation Manager Large Heavy Civil Construction company and materials provider is lo… https://t.co/XQ7KYBM5ec neg 0.8
# College Transportation: 4 Ideas for Getting around Campus Quickly https://t.co/jGaz7c7bYS https://t.co/5L4EMucBUc neg 0.8
# RT @KristaSimpson: The Ministry of Transportation confirms the scheduled closure of the Victoria St. bridge has been postponed until tomorr… neg 0.8
# Can you recommend anyone for this #job? MNGLE PT Local Sort Supervisor - https://t.co/iLK2s27ESM #Transportation… https://t.co/8GoLru4YUq neg 1.0
# Want to work at Forward Air Transportation Services? We're #hiring in #Cleveland, OH! Click for details:… https://t.co/SXutLotEn7 neg 0.8
# A certain respect I have for the women who can do their makeup while on public transportation. neg 0.6
# Interested in a #job in #Westborough, MA? This could be a great fit: https://t.co/9EGW8tFJnW #Transportation #Hiring #CareerArc neg 1.0
# @MSNBC @Google @sundarpichai https://t.co/DgfzYICAoL neg 0.8
# Instant transportation to Tuscany 😍 #frescobaldi @ Frescobaldi London https://t.co/Exxc8EEib0 neg 0.8
# @emilia_suze @cathmckenna @nationalpost Problem is the carbon tax effect's the necessities in life like food and tr… https://t.co/7N4gSJ9osz neg 1.0
# See our latest #EvergreenPark, IL #job and click to apply: TRANSPORTATION AIDE - https://t.co/9NH2FXUKQF #Transportation #Hiring neg 1.0
# Planes, trains, and automobiles 🌎🌍🌏
# —
# —
# What’s your favorite mode of transportation?… https://t.co/xJBwsNLzYL pos 0.6
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     255         try:
# --> 256             return self.connection.recv_into(*args, **kwargs)
#     257         except OpenSSL.SSL.SysCallError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1334             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1335         self._raise_ssl_error(self._ssl, result)
#    1336
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1148         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1149             raise WantReadError()
#    1150         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in _error_catcher(self)
#     297             try:
# --> 298                 yield
#     299
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     379                 cache_content = False
# --> 380                 data = self._fp.read(amt)
#     381                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# C:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in readinto(self, b)
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     270             if not rd:
# --> 271                 raise timeout('The read operation timed out')
#     272             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# <ipython-input-4-3c139c6cdbb5> in <module>()
#      38
#      39 twitterStream = Stream(auth, listener())
# ---> 40 twitterStream.filter(track=["transportation"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     292             # call a handler first so that the exception can be logged.
#     293             self.listener.on_exception(exception)
# --> 294             raise exception
#     295
#     296     def _data(self, data):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     395                         # raised during streaming, so all calls with incorrect
#     396                         # Content-Length are caught.
# --> 397                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     398
#     399         if data:
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      98                 value = type()
#      99             try:
# --> 100                 self.gen.throw(type, value, traceback)
#     101                 raise RuntimeError("generator didn't stop after throw()")
#     102             except StopIteration as exc:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in _error_catcher(self)
#     301                 # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     302                 # there is yet no clean way to get at it from this context.
# --> 303                 raise ReadTimeoutError(self._pool, None, 'Read timed out.')
#     304
#     305             except BaseSSLError as e:
#
# ReadTimeoutError: HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
